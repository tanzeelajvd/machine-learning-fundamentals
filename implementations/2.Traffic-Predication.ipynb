# %% [markdown]
# # CAP 781
# # LAB - 01
# # Data Pre-processing
# ## Importing and Exporting Data in Python, Data Wrangling, Exploratory Data Analysis

# %% [markdown]
# ## Author
#
# - **Name**: `Tanzeela Javid Kaloo`
# - **Department**: Systems and Architecture
# - **University**: Lovely Professional University
# - **Email**: tanzeela.jvd@gmail.com

# %% [markdown]
# # Traffic Prediction

# %% [markdown]
# ## Loading Datasets

# %%
import numpy as np
import pandas as pd

# %%
traffic_data1 = pd.read_csv('datasets/Traffic.csv')

# %%
traffic_data1.head(10)
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        31          0         4
# 1  12:15:00 AM    10         Tuesday        49          0         3
# 2  12:30:00 AM    10         Tuesday        46          0         3
# 3  12:45:00 AM    10         Tuesday        51          0         2
# 4   1:00:00 AM    10         Tuesday        57          6        15
# 5   1:15:00 AM    10         Tuesday        44          0         5
# 6   1:30:00 AM    10         Tuesday        37          0         1
# 7   1:45:00 AM    10         Tuesday        42          4         4
# 8   2:00:00 AM    10         Tuesday        51          0         9
# 9   2:15:00 AM    10         Tuesday        34          0         4
#
#    TruckCount  Total Traffic Situation
# 0           4     39               low
# 1           3     55               low
# 2           6     55               low
# 3           5     58               low
# ...

# %%
# Check for duplicate rows
duplicate_rows = traffic_data1.duplicated()

# Count the number of duplicate rows
num_duplicate_rows = duplicate_rows.sum()

if num_duplicate_rows > 0:
    print("The dataset contains duplicate rows.")
    print("Number of duplicate rows:", num_duplicate_rows)
else:
    print("The dataset does not contain any duplicate rows.")
# Out:
# The dataset does not contain any duplicate rows.

# %%
traffic_data2 = pd.read_csv('datasets/TrafficTwoMonth.csv')

# %%
traffic_data2.head(10)
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        13          2         2
# 1  12:15:00 AM    10         Tuesday        14          1         1
# 2  12:30:00 AM    10         Tuesday        10          2         2
# 3  12:45:00 AM    10         Tuesday        10          2         2
# 4   1:00:00 AM    10         Tuesday        11          2         1
# 5   1:15:00 AM    10         Tuesday        15          1         1
# 6   1:30:00 AM    10         Tuesday        14          2         2
# 7   1:45:00 AM    10         Tuesday        13          2         1
# 8   2:00:00 AM    10         Tuesday         7          0         0
# 9   2:15:00 AM    10         Tuesday        13          0         0
#
#    TruckCount  Total Traffic Situation
# 0          24     41            normal
# 1          36     52            normal
# 2          32     46            normal
# 3          36     50            normal
# ...

# %%
# Check for duplicate rows
duplicate_rows = traffic_data2.duplicated()

# Count the number of duplicate rows
num_duplicate_rows = duplicate_rows.sum()

if num_duplicate_rows > 0:
    print("The dataset contains duplicate rows.")
    print("Number of duplicate rows:", num_duplicate_rows)
else:
    print("The dataset does not contain any duplicate rows.")
# Out:
# The dataset does not contain any duplicate rows.

# %%
traffic_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2976 entries, 0 to 2975
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               2976 non-null   object
#  1   Date               2976 non-null   int64
#  2   Day of the week    2976 non-null   object
#  3   CarCount           2976 non-null   int64
#  4   BikeCount          2976 non-null   int64
#  5   BusCount           2976 non-null   int64
#  6   TruckCount         2976 non-null   int64
#  7   Total              2976 non-null   int64
#  8   Traffic Situation  2976 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 209.4+ KB

# %%
traffic_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5952 entries, 0 to 5951
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               5952 non-null   object
#  1   Date               5952 non-null   int64
#  2   Day of the week    5952 non-null   object
#  3   CarCount           5952 non-null   int64
#  4   BikeCount          5952 non-null   int64
#  5   BusCount           5952 non-null   int64
#  6   TruckCount         5952 non-null   int64
#  7   Total              5952 non-null   int64
#  8   Traffic Situation  5952 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 418.6+ KB

# %% [markdown]
# ## Merging Datasets to Create a Single Dataset

# %%
# Merge the datasets
traffic_data = pd.concat([traffic_data1, traffic_data2], ignore_index=True)

# Save the merged dataset to a new CSV file
traffic_data.to_csv("datasets/MergedTrafficData.csv", index=False)

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8928 entries, 0 to 8927
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               8928 non-null   object
#  1   Date               8928 non-null   int64
#  2   Day of the week    8928 non-null   object
#  3   CarCount           8928 non-null   int64
#  4   BikeCount          8928 non-null   int64
#  5   BusCount           8928 non-null   int64
#  6   TruckCount         8928 non-null   int64
#  7   Total              8928 non-null   int64
#  8   Traffic Situation  8928 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 627.9+ KB

# %%
traffic_data.head()
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        31          0         4
# 1  12:15:00 AM    10         Tuesday        49          0         3
# 2  12:30:00 AM    10         Tuesday        46          0         3
# 3  12:45:00 AM    10         Tuesday        51          0         2
# 4   1:00:00 AM    10         Tuesday        57          6        15
#
#    TruckCount  Total Traffic Situation
# 0           4     39               low
# 1           3     55               low
# 2           6     55               low
# 3           5     58               low
# 4          16     94            normal

# %%
# Setting max column width to avoid truncation of column names
pd.set_option('max_colwidth', 100)

# Creating an empty DataFrame
data_descpt = pd.DataFrame()

# Total number of Parameters (columns) in the dataset
data_descpt["Total Number of Parameters"] = [traffic_data.shape[1]]

# Checking the number of numerical variables using len() and select_dtypes
data_descpt["Number of Numerical Variables"] = [len(traffic_data.select_dtypes('number').columns)]

# Numerical columns in the dataset
data_descpt["Numerical Columns Name"] = [traffic_data.select_dtypes('number').columns.tolist()]

# Checking the number of Categorical variables using len() and select_dtypes
data_descpt["Number of Categorical Variables"] = [len(traffic_data.select_dtypes('object').columns)]

# Categorical columns in the dataset
data_descpt["Categorical Columns Name"] = [traffic_data.select_dtypes('object').columns.tolist()] 

# Total number of rows in the dataset
data_descpt["Total Number of Data Instances"] = [traffic_data.shape[0]]

# Total number of Cells in the dataset
data_descpt["Total Number of Cells"] = [(traffic_data.shape[0])*(len(traffic_data.select_dtypes('object').columns))]

# Calculating the number of missing cells/null values in the dataset
data_descpt["Missing Cells"] = [traffic_data.isnull().sum().sum()]

# Converting the number of missing cells into a percentage
data_descpt["Missing Cells (%)"] = [(traffic_data.isnull().sum().sum()) * 100 / (traffic_data.shape[0] * traffic_data.shape[1])]

# Calculating the number of duplicate rows in the dataset
data_descpt["Duplicate Rows"] = [traffic_data.duplicated().sum()]

# Renaming the column name and displaying the DataFrame
display(data_descpt.T.rename(columns={0: 'Dataset Statistics'}))
# Out:
#                                                                        Dataset Statistics
# Total Number of Parameters                                                              9
# Number of Numerical Variables                                                           6
# Numerical Columns Name           [Date, CarCount, BikeCount, BusCount, TruckCount, Total]
# Number of Categorical Variables                                                         3
# Categorical Columns Name                       [Time, Day of the week, Traffic Situation]
# Total Number of Data Instances                                                       8928
# Total Number of Cells                                                               26784
# Missing Cells                                                                           0
# Missing Cells (%)                                                                     0.0
# ...

# %%
# # Identify duplicate rows
# duplicate_rows = traffic_data[traffic_data.duplicated()]

# # View duplicate rows
# print("Duplicate Rows:")
# duplicate_rows

# %%
# Drop duplicate rows
traffic_data = traffic_data.drop_duplicates()

# Save the cleaned dataset to a new CSV file
traffic_data.to_csv("datasets/FinalTrafficData.csv", index=False)

print("Duplicate rows have been dropped. Cleaned dataset saved to FinalTrafficData.csv.")
# Out:
# Duplicate rows have been dropped. Cleaned dataset saved to FinalTrafficData.csv.

# %%
# Setting max column width to avoid truncation of column names
pd.set_option('max_colwidth', 100)

# Creating an empty DataFrame
data_descpt = pd.DataFrame()

# Total number of Parameters (columns) in the dataset
data_descpt["Total Number of Parameters"] = [traffic_data.shape[1]]

# Checking the number of numerical variables using len() and select_dtypes
data_descpt["Number of Numerical Variables"] = [len(traffic_data.select_dtypes('number').columns)]

# Numerical columns in the dataset
data_descpt["Numerical Columns Name"] = [traffic_data.select_dtypes('number').columns.tolist()]

# Checking the number of Categorical variables using len() and select_dtypes
data_descpt["Number of Categorical Variables"] = [len(traffic_data.select_dtypes('object').columns)]

# Categorical columns in the dataset
data_descpt["Categorical Columns Name"] = [traffic_data.select_dtypes('object').columns.tolist()] 

# Total number of rows in the dataset
data_descpt["Total Number of Data Instances"] = [traffic_data.shape[0]]

# Total number of Cells in the dataset
data_descpt["Total Number of Cells"] = [(traffic_data.shape[0])*(len(traffic_data.select_dtypes('object').columns))]

# Calculating the number of missing cells/null values in the dataset
data_descpt["Missing Cells"] = [traffic_data.isnull().sum().sum()]

# Converting the number of missing cells into a percentage
data_descpt["Missing Cells (%)"] = [(traffic_data.isnull().sum().sum()) * 100 / (traffic_data.shape[0] * traffic_data.shape[1])]

# Calculating the number of duplicate rows in the dataset
data_descpt["Duplicate Rows"] = [traffic_data.duplicated().sum()]

# Renaming the column name and displaying the DataFrame
display(data_descpt.T.rename(columns={0: 'Dataset Statistics'}))
# Out:
#                                                                        Dataset Statistics
# Total Number of Parameters                                                              9
# Number of Numerical Variables                                                           6
# Numerical Columns Name           [Date, CarCount, BikeCount, BusCount, TruckCount, Total]
# Number of Categorical Variables                                                         3
# Categorical Columns Name                       [Time, Day of the week, Traffic Situation]
# Total Number of Data Instances                                                       6324
# Total Number of Cells                                                               18972
# Missing Cells                                                                           0
# Missing Cells (%)                                                                     0.0
# ...

# %% [markdown]
# # Final Dataset

# %%
traffic_data.head()
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        31          0         4
# 1  12:15:00 AM    10         Tuesday        49          0         3
# 2  12:30:00 AM    10         Tuesday        46          0         3
# 3  12:45:00 AM    10         Tuesday        51          0         2
# 4   1:00:00 AM    10         Tuesday        57          6        15
#
#    TruckCount  Total Traffic Situation
# 0           4     39               low
# 1           3     55               low
# 2           6     55               low
# 3           5     58               low
# 4          16     94            normal

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6324 entries, 0 to 8927
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               6324 non-null   object
#  1   Date               6324 non-null   int64
#  2   Day of the week    6324 non-null   object
#  3   CarCount           6324 non-null   int64
#  4   BikeCount          6324 non-null   int64
#  5   BusCount           6324 non-null   int64
#  6   TruckCount         6324 non-null   int64
#  7   Total              6324 non-null   int64
#  8   Traffic Situation  6324 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 494.1+ KB

# %% [markdown]
# # Explotarary Data Analysis

# %% [markdown]
# ## Preprocessing Time Column
# Time column can provide additional insights into the dataset, especially regarding temporal patterns and trends in traffic data.

# %%
# Convert 'Time' column to datetime if it's not already
try:
    traffic_data['Time'] = pd.to_datetime(traffic_data['Time'], format='%I:%M:%S %p', errors='raise')
except ValueError as e:
    print("Error occurred during datetime conversion:", e)

# Now extract hour and minute information
traffic_data['Hour'] = traffic_data['Time'].dt.hour
traffic_data['Minute'] = traffic_data['Time'].dt.minute

# Printing the DataFrame to verify the changes
traffic_data.head()
# Out:
#                  Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0 1900-01-01 00:00:00    10         Tuesday        31          0         4
# 1 1900-01-01 00:15:00    10         Tuesday        49          0         3
# 2 1900-01-01 00:30:00    10         Tuesday        46          0         3
# 3 1900-01-01 00:45:00    10         Tuesday        51          0         2
# 4 1900-01-01 01:00:00    10         Tuesday        57          6        15
#
#    TruckCount  Total Traffic Situation  Hour  Minute
# 0           4     39               low     0       0
# 1           3     55               low     0      15
# 2           6     55               low     0      30
# 3           5     58               low     0      45
# 4          16     94            normal     1       0

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6324 entries, 0 to 8927
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               6324 non-null   datetime64[ns]
#  1   Date               6324 non-null   int64
#  2   Day of the week    6324 non-null   object
#  3   CarCount           6324 non-null   int64
#  4   BikeCount          6324 non-null   int64
#  5   BusCount           6324 non-null   int64
#  6   TruckCount         6324 non-null   int64
#  7   Total              6324 non-null   int64
#  8   Traffic Situation  6324 non-null   object
#  9   Hour               6324 non-null   int32
#  10  Minute             6324 non-null   int32
# dtypes: datetime64[ns](1), int32(2), int64(6), object(2)
# memory usage: 543.5+ KB

# %% [markdown]
# ## Descriptive Statistical Analysis
#
#
# 1. `What is the average CarCount, BikeCount, BusCount, TruckCount, and Total count?`
# 2. `What is the median count for each vehicle type?`
# 3. `What is the maximum and minimum count observed for each vehicle type?`
# 4. `How does the distribution of counts vary across different hours of the day or days of the week?`
# 5. `How do the traffic counts vary over different hours of the day or days of the week?`
# 6. `Are there any specific time periods when certain vehicle types have significantly higher or lower counts?`
# 7. `How does the traffic situation (e.g., Traffic Situation column) influence the counts?`
#
# ## Comparative Analysis:
# 1. `How do the traffic counts differ between weekdays and weekends?`
# 2. `Is there a difference in traffic patterns between different days of the week?`

# %%
traffic_data = traffic_data.drop(columns=['Time'])
traffic_data.head(10)
# Out:
#    Date Day of the week  CarCount  BikeCount  BusCount  TruckCount  Total  \
# 0    10         Tuesday        31          0         4           4     39
# 1    10         Tuesday        49          0         3           3     55
# 2    10         Tuesday        46          0         3           6     55
# 3    10         Tuesday        51          0         2           5     58
# 4    10         Tuesday        57          6        15          16     94
# 5    10         Tuesday        44          0         5           4     53
# 6    10         Tuesday        37          0         1           4     42
# 7    10         Tuesday        42          4         4           5     55
# 8    10         Tuesday        51          0         9           7     67
# 9    10         Tuesday        34          0         4           7     45
#
#   Traffic Situation  Hour  Minute
# 0               low     0       0
# 1               low     0      15
# 2               low     0      30
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group data by hour and calculate total traffic count
hourly_total_traffic = traffic_data.groupby('Hour')['Total'].sum().reset_index()

# Plot
plt.figure(figsize=(15, 6))
plt.plot(hourly_total_traffic['Hour'].values, hourly_total_traffic['Total'].values, linestyle='-', color='black')
plt.title('Total Traffic Count Over Hours of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Total Traffic Count')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'hourly_total_traffic' is your DataFrame containing the columns "Hour, Total"

# Plot a pie chart for total traffic count over hours of the day
plt.figure(figsize=(8, 8))
plt.pie(hourly_total_traffic['Total'], labels=hourly_total_traffic['Hour'], autopct='%1.1f%%', startangle=140)
plt.title('Total Traffic Count Over Hours of the Day')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'traffic_data' is your DataFrame containing the columns "Hour, CarCount, BikeCount, BusCount, TruckCount, Total"

# Group data by hour and calculate total traffic count
hourly_traffic_counts = traffic_data.groupby('Hour')[['CarCount', 'BikeCount', 'BusCount', 'TruckCount', 'Total']].sum().reset_index()

# Plot
plt.figure(figsize=(15, 8))

# Plot lines for each column
for column in ['CarCount', 'BikeCount', 'BusCount', 'TruckCount', 'Total']:
    plt.plot(hourly_traffic_counts['Hour'].values, hourly_traffic_counts[column].values, label=column)

plt.title('Traffic Counts Over Hours of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Traffic Count')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'hourly_traffic_counts' is your DataFrame containing the columns "Hour, CarCount, BikeCount, BusCount, TruckCount, Total"

# Plot a pie chart for each hour
for hour in hourly_traffic_counts['Hour']:
    # Filter data for the current hour and exclude the 'Total' column
    hour_data = hourly_traffic_counts[hourly_traffic_counts['Hour'] == hour].drop(columns=['Total'])
    
    # Create a figure and axis for the pie chart
    plt.figure(figsize=(6, 6))
    plt.pie(hour_data.values[0], labels=hour_data.columns, autopct='%1.1f%%', startangle=140)
    plt.title(f'Traffic Counts for Hour {hour}')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
    plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'traffic_data' is your DataFrame containing the columns "Day of the week, CarCount, BikeCount, BusCount, TruckCount, Total"

# Group data by day of the week and calculate total traffic count
daily_traffic_counts = traffic_data.groupby('Day of the week')[['CarCount', 'BikeCount', 'BusCount', 'TruckCount', 'Total']].sum().reset_index()

# Plot
plt.figure(figsize=(15, 6))

# Plot lines for each column
for column in ['CarCount', 'BikeCount', 'BusCount', 'TruckCount', 'Total']:
    plt.plot(daily_traffic_counts['Day of the week'].values, daily_traffic_counts[column].values, label=column)

plt.title('Traffic Counts Over Days of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Traffic Count')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Group data by day of the week and calculate total traffic count
daily_traffic_totals = daily_traffic_counts[['CarCount', 'BikeCount', 'BusCount', 'TruckCount']].sum()

# Plot
plt.figure(figsize=(8, 8))

# Plot a pie chart for the total traffic counts
plt.pie(daily_traffic_totals, labels=daily_traffic_totals.index, autopct='%1.1f%%', startangle=140)

plt.title('Total Traffic Distribution Across Days of the Week')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
import matplotlib.pyplot as plt


# Plot a pie chart for each day
for day in daily_traffic_counts['Day of the week']:
    # Filter data for the current day
    day_data = daily_traffic_counts[daily_traffic_counts['Day of the week'] == day].drop(columns=['Total'])
    
    # Create a figure and axis for the pie chart
    plt.figure(figsize=(6, 6))
    plt.pie(day_data.drop(columns=['Day of the week']).values[0], labels=day_data.drop(columns=['Day of the week']).columns, autopct='%1.1f%%', startangle=140)
    plt.title(f'Traffic Counts for {day}')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
    plt.show()

# %% [markdown]
# ## Visualizing Data

# %%
# Grouping by 'Hour' and calculating the mean counts for each vehicle type
hourly_traffic_counts = traffic_data.groupby('Hour').agg({
    'CarCount': 'mean',
    'BikeCount': 'mean',
    'BusCount': 'mean',
    'TruckCount': 'mean',
    'Total': 'mean'  
})

hourly_traffic_counts = hourly_traffic_counts.astype(int)
hourly_traffic_counts
# Out:
#       CarCount  BikeCount  BusCount  TruckCount  Total
# Hour
# 0           13          1         0          25     41
# 1           13          1         0          25     41
# 2           13          1         0          26     42
# 3           14          1         1          26     43
# 4           65          8         3          18     96
# 5           79         10         5          16    111
# 6          109         20        22           8    161
# 7          109         20        22           9    161
# 8          109         20        23           8    162
# 9           71         15        19          12    120
# 10          63         15        18          16    113
# 11          57         11         8          24    102
# 12          58         11         9          24    103
# 13          65         17        18          16    117
# 14          67         19        19          14    120
# 15          69         16        18          14    117
# ...

# %%
import matplotlib.pyplot as plt

# Plotting the mean counts for each vehicle type over the hours using a bar graph
plt.figure(figsize=(12, 6))

# Get the hours
hours = hourly_traffic_counts.index

# Get the vehicle types
vehicle_types = hourly_traffic_counts.columns

# Set the width of the bars
bar_width = 0.2

# Set the positions of the bars on the x-axis
r = range(len(hours))

# Plotting each vehicle type separately
for i, vehicle_type in enumerate(vehicle_types):
    plt.bar([x + i * bar_width for x in r], hourly_traffic_counts[vehicle_type], width=bar_width, label=vehicle_type)

# Adding labels and title
plt.xlabel('Hour')
plt.ylabel('Mean Count')
plt.title('Mean Counts of Vehicle Types Over Hours')

# Adding x-axis ticks and labels
plt.xticks([x + 1.5 * bar_width for x in r], hours)

# Adding legend
plt.legend()

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Grouping by 'Hour' and calculating the mean counts for each vehicle type
date_traffic_counts = traffic_data.groupby('Date').agg({
    'CarCount': 'mean',
    'BikeCount': 'mean',
    'BusCount': 'mean',
    'TruckCount': 'mean',
    'Total': 'mean'  
})

date_traffic_counts = date_traffic_counts.astype(int)
date_traffic_counts
# Out:
#       CarCount  BikeCount  BusCount  TruckCount  Total
# Date
# 1           64         11        13          18    108
# 2           63         11        13          18    106
# 3           62         16         6          17    102
# 4           64         11        13          18    108
# 5           67         11        13          19    111
# 6           65         11        13          18    109
# 7           65         10        14          18    108
# 8           65         11        12          18    108
# 9           65         11        13          18    109
# 10          68         12        14          17    112
# 11          65         11        13          18    109
# 12          64         11        13          18    108
# 13          61         15         6          17    101
# 14          63         11        13          18    106
# 15          65         11        14          18    110
# 16          64         10        13          19    108
# ...

# %%
import matplotlib.pyplot as plt

# Plotting the mean counts for each vehicle type over the hours using a bar graph
plt.figure(figsize=(12, 6))

# Get the hours
date = date_traffic_counts.index

# Get the vehicle types
vehicle_types = date_traffic_counts.columns

# Set the width of the bars
bar_width = 0.2

# Set the positions of the bars on the x-axis
r = range(len(date))

# Plotting each vehicle type separately
for i, vehicle_type in enumerate(vehicle_types):
    plt.bar([x + i * bar_width for x in r], date_traffic_counts[vehicle_type], width=bar_width, label=vehicle_type)

# Adding labels and title
plt.xlabel('Hour')
plt.ylabel('Mean Count')
plt.title('Mean Counts of Vehicle Types Over Hours')

# Adding x-axis ticks and labels
plt.xticks([x + 1.5 * bar_width for x in r], date)

# Adding legend
plt.legend()

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Grouping by 'Hour' and calculating the mean counts for each vehicle type
daily_traffic_counts = traffic_data.groupby('Day of the week').agg({
    'CarCount': 'mean',
    'BikeCount': 'mean',
    'BusCount': 'mean',
    'TruckCount': 'mean',
    'Total': 'mean'  
})

daily_traffic_counts = daily_traffic_counts.astype(int)
daily_traffic_counts
# Out:
#                  CarCount  BikeCount  BusCount  TruckCount  Total
# Day of the week
# Friday                 62         16         6          17    102
# Monday                 64         11        13          19    107
# Saturday               64         11        13          18    108
# Sunday                 65         11        13          19    109
# Thursday               64         11        13          18    107
# Tuesday                64         11        13          18    108
# Wednesday              65         11        13          18    108

# %%
import matplotlib.pyplot as plt

# Plotting the mean counts for each vehicle type over the hours using a bar graph
plt.figure(figsize=(12, 6))
# fig, ax = plt.subplots(layout='constrained')

# Get the hours
days = daily_traffic_counts.index

# Get the vehicle types
vehicle_types = daily_traffic_counts.columns

# Set the width of the bars
bar_width = 0.2

# Set the positions of the bars on the x-axis
r = range(len(days))

# Plotting each vehicle type separately
for i, vehicle_type in enumerate(vehicle_types):
    bars = plt.bar([x + i * bar_width for x in r], daily_traffic_counts[vehicle_type], width=bar_width, label=vehicle_type)
    # Add labels to each bar
    for bar in bars:
        height = bar.get_height()
        plt.annotate('{}'.format(height),
                     xy=(bar.get_x() + bar.get_width() / 2, height),
                     xytext=(0, 3),  # 3 points vertical offset
                     textcoords="offset points",
                     ha='center', va='bottom')

# Adding labels and title
plt.xlabel('Day of the Week')
plt.ylabel('Mean Count')
plt.title('Mean Counts of Vehicle Types Over Hours')

# Adding x-axis ticks and labels
plt.xticks([x + 1.5 * bar_width for x in r], days)

# Adding legend
plt.legend()

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Analysis:
# 1. `Is there a correlation between different types of counts (e.g., CarCount vs. BikeCount)?`
# 2. `How does the correlation between counts vary across different hours or days?`

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix between counts
correlation_matrix = traffic_data[['CarCount', 'BikeCount', 'BusCount', 'TruckCount']].corr()
correlation_matrix
# Out:
#             CarCount  BikeCount  BusCount  TruckCount
# CarCount    1.000000   0.705941  0.664491   -0.583984
# BikeCount   0.705941   1.000000  0.581289   -0.585670
# BusCount    0.664491   0.581289  1.000000   -0.533847
# TruckCount -0.583984  -0.585670 -0.533847    1.000000

# %%
# Visualize correlation matrix as a heatmap
plt.figure(figsize=(10, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='bone', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Counts')
plt.xlabel('Vehicle Type')
plt.ylabel('Vehicle Type')
plt.show()

# %%
# Group data by hour and calculate correlation matrix between counts for each hour
hourly_correlation_matrix = traffic_data.groupby('Hour')[['CarCount', 'BikeCount', 'BusCount', 'TruckCount']].corr()

# Visualize hourly correlation matrices as heatmaps
plt.figure(figsize=(25, 15))
for i, (hour, matrix) in enumerate(hourly_correlation_matrix.groupby(level=0)):
    plt.subplot(8, 3, i+1)
    sns.heatmap(matrix, annot=True, cmap='bone', fmt=".2f", linewidths=0.5)
    plt.title(f'Hour {hour}')
    plt.xlabel('Vehicle Type')
    plt.ylabel('Vehicle Type')
plt.tight_layout()
plt.show()

# %%
# Group data by day of the week and calculate correlation matrix between counts for each day
daily_correlation_matrix = traffic_data.groupby('Day of the week')[['CarCount', 'BikeCount', 'BusCount', 'TruckCount']].corr()

# Visualize hourly correlation matrices as heatmaps
plt.figure(figsize=(20, 15))
for i, (day, matrix) in enumerate(daily_correlation_matrix.groupby(level=0)):
    plt.subplot(8, 3, i+1)
    sns.heatmap(matrix, annot=True, cmap='bone', fmt=".2f", linewidths=0.5)
    plt.title(f'Day {day}')
    plt.xlabel('Vehicle Type')
    plt.ylabel('Vehicle Type')
plt.tight_layout()
plt.show()

# %%
statistics = traffic_data.describe()
statistics
# Out:
#               Date     CarCount    BikeCount     BusCount   TruckCount  \
# count  6324.000000  6324.000000  6324.000000  6324.000000  6324.000000
# mean     16.043327    64.355629    12.013283    12.557875    18.658128
# std       8.956907    44.307088    11.363955    12.319831    10.724822
# min       1.000000     5.000000     0.000000     0.000000     0.000000
# 25%       8.000000    18.000000     3.000000     1.000000    10.000000
# 50%      16.000000    61.000000     9.000000    10.000000    18.000000
# 75%      24.000000   101.250000    19.000000    20.000000    27.000000
# max      31.000000   180.000000    70.000000    50.000000    60.000000
#
#              Total         Hour       Minute
# count  6324.000000  6324.000000  6324.000000
# mean    107.584915    11.495572    22.514231
# std      55.850784     7.016675    16.767586
# min      21.000000     0.000000     0.000000
# 25%      53.000000     5.000000    11.250000
# 50%     103.000000    11.000000    30.000000
# ...

# %% [markdown]
# ## Check the Spread of Numerical Data

# %%
# Select all quantitative columns for checking the spread
numeric_columns = traffic_data.select_dtypes(include=np.number).columns.tolist()

# Define a color palette with multiple colors
color_palette = sns.color_palette("coolwarm", len(numeric_columns))

plt.figure(figsize=(15, 10))

for i, variable in enumerate(numeric_columns):
    plt.subplot(5, 2, i + 1)  
    sns.distplot(traffic_data[variable].values, kde=False, color=color_palette[i])  
#     sns.distplot(traffic_data[variable].values, kde=False)  
    plt.tight_layout()
    plt.title(variable)

plt.show()
# Out:
# C:\Users\tanzeelajavid\AppData\Local\Temp\ipykernel_3068\527616633.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(traffic_data[variable].values, kde=False, color=color_palette[i])

# %%
# Select categorical columns for checking the distribution
categorical_columns = traffic_data.select_dtypes(include='object').columns.tolist()

plt.figure(figsize=(15, 8))

for i, column in enumerate(categorical_columns):
    plt.subplot(2, len(categorical_columns)//2, i+1)  
#     sns.countplot(x=traffic_data[column], palette='pastel')  
    sns.countplot(x=traffic_data[column])  
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Select numerical columns for the scatter plots
numerical_columns = traffic_data.select_dtypes(include='number').columns.tolist()

plt.figure(figsize=(20, 25))

for i, variable in enumerate(numerical_columns):
    plt.subplot(5, 2, i + 1)
    sns.scatterplot(x=traffic_data[variable], y=traffic_data['Traffic Situation'], color='red', marker='*').set(title='Traffic Situation vs ' + variable)
    plt.tight_layout()

plt.show()

# %% [markdown]
# ## Predictive Analysis:
# 1. `Can we predict future traffic counts based on historical data?`
# 2. `What factors contribute most to fluctuations in traffic counts?`
# 3. `Can we identify any anomalies or outliers in the data that might affect future predictions`

# %% [markdown]
# # Split Dataset

# %%
from sklearn.model_selection import train_test_split

# Split the data into features (X) and target variable (y)
X = traffic_data.drop("Traffic Situation", axis=1) 
y = traffic_data["Traffic Situation"]

# Perform a random train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1711)

print(f'There are {traffic_data.shape[0]} rows and {traffic_data.shape[1]} columns')

# Print the shape of the training and testing sets
print("Shape of Training Set: X_train:{0} and y_train:{1}".format(X_train.shape, y_train.shape))
print("Shape of Testing Set: X_test:{0} and y_test:{1}".format(X_test.shape, y_test.shape))
# Out:
# There are 6324 rows and 10 columns
# Shape of Training Set: X_train:(4743, 9) and y_train:(4743,)
# Shape of Testing Set: X_test:(1581, 9) and y_test:(1581,)

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import RandomizedSearchCV


# Define numerical and categorical features
numerical_features = ['Date', 'CarCount', 'BikeCount', 'BusCount', 'TruckCount', 'Total', 'Hour', 'Minute']
categorical_features = ['Day of the week']


# Define preprocessing steps for numerical and categorical features
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehotencoder', OneHotEncoder(handle_unknown='ignore'))
])

# Combine preprocessing steps for numerical and categorical features
preprocessor = ColumnTransformer(transformers=[
    ('numerical', numerical_transformer, numerical_features),
    ('categorical', categorical_transformer, categorical_features)
])

# %% [markdown]
# #  Build Model with Preprocessing Pipeline
#
# ## 1. Hyperparameter Tuning

# %%
# Define the model
model = RandomForestClassifier(random_state=1711)

# Create a pipeline with preprocessing and the model
pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('randomforestclassifier', model)])

# Define the hyperparameter grid for RandomizedSearchCV
param_grid = {
    'randomforestclassifier__n_estimators': list(range(60, 105)),
    'randomforestclassifier__criterion': ['gini', 'entropy'],
    'randomforestclassifier__max_depth': list(range(1, 10)),
    'randomforestclassifier__max_features': ['sqrt', 'log2'],
    'randomforestclassifier__min_samples_split': list(range(2, 10)),
    'randomforestclassifier__min_samples_leaf': list(range(1, 5)),
    'randomforestclassifier__bootstrap': [True, False]
}

# Define cross-validation strategy
kfold = KFold(n_splits=5, shuffle=True, random_state=1711)

# Perform RandomizedSearchCV
rd_search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_grid,
    scoring='accuracy',  # or any other appropriate metric for classification - f1_macro', 'precision_macro', or 'recall_macro'
    cv=kfold,
    n_iter=100,  # Adjust the number of iterations as needed
    random_state=1711
)

# Fit the RandomizedSearchCV on the training data
rd_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=1711, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('numerical',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['Date',
#                                                                                 'CarCount',
#                                                                                 'BikeCount',
# ...

# %%
print("Validation Accuracy: %.2f %%" % (rd_search.best_score_*100))
# Out:
# Validation Accuracy: 93.42 %

# %%
print("Accuracy on train+val data: %.2f %%" % (rd_search.score(X_train, y_train)*100))
# Out:
# Accuracy on train+val data: 94.50 %

# %% [markdown]
# ## 2. Best Estimator

# %%
# Access the best estimator from the randomized search
best_estimator = rd_search.best_estimator_
best_estimator
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Date', 'CarCount',
#                                                    'BikeCount', 'BusCount',
#                                                    'TruckCount', 'Total',
#                                                    'Hour', 'Minute']),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('imputer',
# ...

# %%
# Use the best estimator to make predictions on the test set
y_pred = best_estimator.predict(X_test)
y_pred
# y_test.head(10)
# Out:
# array(['normal', 'normal', 'normal', ..., 'low', 'normal', 'high'],
#       shape=(1581,), dtype=object)

# %% [markdown]
# ## Save Model

# %%
import joblib

# Assuming your model variable is called 'model'
joblib.dump(best_estimator, 'best_model.pkl')
# Out:
# ['best_model.pkl']

# %%
# Evaluate the model performance
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Assuming y_test and y_pred are your actual and predicted target variables, respectively
accuracy = accuracy_score(y_test, y_pred)
accuracy = accuracy*100
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Model Performance on Test Data:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Model Performance on Test Data:
# Accuracy: 92.0303605313093
# Precision: 0.9273124556769506
# Recall: 0.920303605313093
# F1 Score: 0.9204476156510112

# %%
from sklearn.model_selection import learning_curve

# Define the RandomForestClassifier model
model = rd_search.best_estimator_

# Compute learning curves
train_sizes, train_scores, val_scores = learning_curve(
    model, X_train, y_train, train_sizes=np.linspace(0.1, 1.0, 10), cv=5
)

# Calculate mean training and validation scores across folds
train_scores_mean = np.mean(train_scores, axis=1)
val_scores_mean = np.mean(val_scores, axis=1)

# Plot learning curves
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_scores_mean, '-', color='y', label='Training score')
plt.plot(train_sizes, val_scores_mean, '-', color='r', label='Cross-validation score')
plt.xlabel('Training examples')
plt.ylabel('Accuracy')
plt.title('Learning curves')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Calculate feature importances
feature_importances = rd_search.best_estimator_.named_steps['randomforestclassifier'].feature_importances_
categorical_feature_names = rd_search.best_estimator_.named_steps['preprocessor'].named_transformers_['categorical'].named_steps['onehotencoder'].get_feature_names_out(input_features=categorical_features)

all_feature_names = np.concatenate([numerical_features, categorical_feature_names])

# Sort the feature importances in descending order
sorted_indices = np.argsort(feature_importances)[::-1]
sorted_feature_importances = feature_importances[sorted_indices]
sorted_feature_names = all_feature_names[sorted_indices]

# Create a DataFrame with feature names and importances
feature_df = pd.DataFrame({'Feature': sorted_feature_names, 'Importance': sorted_feature_importances})

# Print the DataFrame
print(feature_df.head(9))

# Plot feature importances
plt.figure(figsize=(12, 8))
plt.barh(feature_df['Feature'][:9], feature_df['Importance'][:9], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top 9 Feature Importances')
plt.gca().invert_yaxis()
plt.show()
# Out:
#                   Feature  Importance
# 0                   Total    0.310067
# 1                CarCount    0.244705
# 2              TruckCount    0.195366
# 3                BusCount    0.136643
# 4               BikeCount    0.050750
# 5                    Hour    0.047322
# 6  Day of the week_Friday    0.008133
# 7                    Date    0.002601
# 8                  Minute    0.001602
